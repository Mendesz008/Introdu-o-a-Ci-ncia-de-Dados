# %% [markdown]
# <a href="https://colab.research.google.com/github/Mendesz008/Introdu-o-a-Ci-ncia-de-Dados/blob/main/C%C3%B3pia_de_ListaExercicios_1_PythonExpress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ## **<center>Lista de Exercícios 1 - Python Express</center>**
#
#
# **<center>Introdução a Ciência de Dados</center>**
# ***
#
# <br>
#
# Segue uma lista de exercícios abordando o conteúdo inicial para a programação em Python.
#
# Cada exercício deve ser respondido em uma célula específica.
#
#
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.
#
#
# 2) Elabore um código que peça um número e então mostre a mensagem: *"O número informado foi [número]."*
#
#
# 3) Elabore um código que peça dois números e imprima a soma.
#
#
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.
#
# 5) Elabore um código que converta metros para centímetros.
#
#
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.
#
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.
#
#
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.
#
#
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# ** Onde C = 5 * ((F-32) / 9)**.
#
#
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
#
#
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
# * o produto do dobro do primeiro com metade do segundo .
# * a soma do triplo do primeiro com o terceiro.
# * o terceiro elevado ao cubo.
#
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

# %%
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.

print("Olá terráqueos")
# Out:
# Olá terráqueos

# %%
# 2) Elabore um código que peça um número e então mostre a mensagem: "O número informado foi [número]."

número = input("Digite um número")
# Out:
# Digite um número 8

# %%
print(f"O número informado foi: {número}")
# Out:
# O número informado foi:  8

# %%
# 3) Elabore um código que peça dois números e imprima a soma.

número1 = int(input("Digite o primeiro número:"))
número2 = int(input("Digite o segundo número:"))
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 8

# %%
soma = número1 + número2

# %%
print(f"A soma de {número1} e {número2} é igual a {soma}.")
# Out:
# A soma de 2 e 8 é igual a 10.

# %%
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.

nota1 = float(input("Digite a nota do 1º bimestre:"))
nota2 = float(input("Digite a nota do 2º bimestre:"))
nota3 = float(input("Digite a nota do 3º bimestre:"))
nota4 = float(input("Digite a nota do 4º bimestre:"))
# Out:
# Digite a nota do 1º bimestre: 9.0
# Digite a nota do 2º bimestre: 8.5
# Digite a nota do 3º bimestre: 8.0
# Digite a nota do 4º bimestre: 7.5

# %%
lista_de_notas = [nota1, nota2, nota3, nota4]

# %%
média = sum(lista_de_notas) / 4

# %%
print(f"A média das notas é: {média}")
# Out:
# A média das notas é: 8.25

# %%
# 5) Elabore um código que converta metros para centímetros.

metros = float(input("Digite a medida em metros:"))
# Out:
# Digite a medida em metros: 1.5

# %%
centímetros = metros * 100

# %%
print(f"{metros} metros equivalem a {centímetros} centímetros")
# Out:
# 1.5 metros equivalem a 150.0 centímetros

# %%
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.

raio = float(input("Digite o raio do círculo:"))
# Out:
# Digite o raio do círculo: 5

# %%
pi = 3.14

# %%
área = pi * (raio ** 2)

# %%
print(f"A área do círculo é: {área}")
# Out:
# A área do círculo é: 78.5

# %%
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

lado = float(input("Digite o valor do lado do quadrado:"))
# Out:
# Digite o valor do lado do quadrado: 4

# %%
área = lado ** 2

# %%
dobro_área = área * 2

# %%
print(f"A área do quadrado é: {área}, e o dobro dessa área é: {dobro_área}.")
# Out:
# A área do quadrado é: 16.0, e o dobro dessa área é: 32.0.

# %%
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.

# %%
valor_hora = float(input("Quanto você ganha por hora? R$"))

horas_trabalhadas = float(input("Quantas horas você trabalha por mês?"))
# Out:
# Quanto você ganha por hora? R$ 10.00
# Quantas horas você trabalha por mês? 220

# %%
salário = valor_hora * horas_trabalhadas

# %%
print(f"Estou muito satisfeito! Trabalhando {horas_trabalhadas} horas a R$ {valor_hora} por hora, o meu salário estimado para este mês é de R$ {salário}")
# Out:
# Estou muito satisfeito! Trabalhando 220.0 horas a R$ 10.0 por hora, o meu salário estimado para este mês é de R$ 2200.0

# %%
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius. ** Onde C = 5 * ((F-32) / 9)**.

Fahrenheit = float(input("Digite a temperatura em Fahrenheit:"))
# Out:
# Digite a temperatura em Fahrenheit: 120

# %%
Celsius = 5 * ((Fahrenheit - 32) / 9)

# %%
Celsius
# Out:
# 48.89

# %%
print(f"A temperatura de {Fahrenheit:.2f} graus Fahrenheit equivale a {Celsius} graus Celsius.")
# Out:
# A temperatura de 120.00 graus Fahrenheit equivale a 48.89 graus Celsius.

# %%
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.

Celsius = float(input("Digite a temperatura em Celsius:"))
# Out:
# Digite a temperatura em Celsius: 48.89

# %%
Fahrenheit = Celsius * (9 / 5) + 32

# %%
48.89 * (9 / 5) + 32
# Out:
# 120.00200000000001

# %%
print(f"A temperatura de {Celsius} graus Celsius equivale a {Fahrenheit:.2f} graus Fahrenheit.")
# Out:
# A temperatura de 48.89 graus Celsius equivale a 120.00 graus Fahrenheit.

# %%
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
#O produto do dobro do primeiro com metade do segundo .
#A soma do triplo do primeiro com o terceiro.
#O terceiro elevado ao cubo.

número1 = int(input("Digite o primeiro número inteiro:"))
número2 = int(input("Digite o segundo número inteiro:"))
número3 = float(input("Digite um número real:"))
# Out:
# Digite o primeiro número inteiro: 2
# Digite o segundo número inteiro: 4
# Digite um número real: 3.5

# %%
resultado1 = (2 * número1) * (número2 / 2)

# %%
(2 * 2) * (4 / 2)
# Out:
# 8.0

# %%
resultado2 = (3 * número1) + número3

# %%
(3 * 2) + 3.5
# Out:
# 9.5

# %%
resultado3 = número3 ** 3

# %%
3.5 ** 3
# Out:
# 42.875

# %%
print(f"O produto do dobro do primeiro com metade do segundo é: {resultado1}")
print(f"A soma do triplo do primeiro com o terceiro é: {resultado2}")
print(f"O terceiro elevado ao cubo é: {resultado3}")
# Out:
# O produto do dobro do primeiro com metade do segundo é: 8.0
# A soma do triplo do primeiro com o terceiro é: 9.5
# O terceiro elevado ao cubo é: 42.875

# %%
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

altura = float(input("Digite a sua altua:"))
# Out:
# Digite a sua altua: 1.89

# %%
peso_ideal = (72.7 * altura) - 58

# %%
(72.7 * 1.89) - 58
# Out:
# 79.40299999999999

# %%
print(f"Para uma pessoa com {altura}m de altura, o peso ideal estimado é de {peso_ideal:.2f}kg.")
# Out:
# Para uma pessoa com 1.89m de altura, o peso ideal estimado é de 79.40kg.
